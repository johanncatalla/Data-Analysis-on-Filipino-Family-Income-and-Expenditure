# %% [markdown]
# # <center> **Data Analysis on Anime Recommendations**
# #### <center> By: Johann Sebastian E. Catalla, BSCS-I
# #### <center> An output for the course CP102: Computer Programming 2
# ***

# %% [markdown]
# <div style="text-align: justify"> The dataset was sourced through kaggle from the Philippine Statistics Authority's (PSA) Family Income and Expenditure Survey (FIES) nationwide. The survey, which is undertaken every three (3) years, is aimed at providing data on family income and expenditure, including, among others, levels of consumption by item of expenditure, sources of income in cash, and related information affecting income and expenditure levels and patterns in the Philippines.
# <br><br>
# The Dataset contains more than 40k observations and 60 variables which is primarily comprised of the household income and expenditures of that specific household. For this analysis, I will be using Python's <b>pandas</b>, <b>numpy</b>, and <b>hvplot</b> libraries. </div>

# %%
import pandas as pd
import hvplot.pandas
import numpy as np

# %% [markdown]
# Displaying the dataset on Filipino Family Income and Expenditure; it contains 41,544 rows and 60 columns.

# %%
dataset = pd.read_csv('anime.csv')
dataset
# Out:
#        MAL_ID                             Name    Score  \
# 0           1                     Cowboy Bebop     8.78
# 1           5  Cowboy Bebop: Tengoku no Tobira     8.39
# 2           6                           Trigun     8.24
# 3           7               Witch Hunter Robin     7.27
# 4           8                   Bouken Ou Beet     6.98
# ...       ...                              ...      ...
# 17557   48481  Daomu Biji Zhi Qinling Shen Shu  Unknown
# 17558   48483                     Mieruko-chan  Unknown
# 17559   48488  Higurashi no Naku Koro ni Sotsu  Unknown
# 17560   48491      Yama no Susume: Next Summit  Unknown
# 17561   48492                    Scarlet Nexus  Unknown
#
#                                                   Genres  \
# 0        Action, Adventure, Comedy, Drama, Sci-Fi, Space
# 1                  Action, Drama, Mystery, Sci-Fi, Space
# 2      Action, Sci-Fi, Adventure, Comedy, Drama, Shounen
# 3      Action, Mystery, Police, Supernatural, Drama, ...
# ...

# %% [markdown]
# Replacing "Unknown"

# %%
dataset = dataset.replace(to_replace="Unknown", value=None).dropna()

# %%
plot = dataset.groupby("Name")[["Score"]].mean().sort_values(by="Score", ascending=False).head(20).sort_values(by="Score")
plot.hvplot.barh(color="aquamarine",height=800, width=1000, xlabel="Anime", ylabel="Average User Score", stacked=True, fontscale=1.3)
# Out:
# :Bars   [Name]   (Score)
